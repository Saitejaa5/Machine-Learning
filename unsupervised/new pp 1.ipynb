# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.decomposition import PCA 
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('marketing_campaign_Dataset.csv')
pd.set_option('display.max_columns', None)
df.sample(5)
# Out:
#         Education Marital_Status     Income  Kidhome  Teenhome Dt_Customer  \
# 79233         PhD          Alone  200926.77        2         1  2012-11-20
# 83689      Master       Together  541237.88        1         0  2013-09-19
# 47005         PhD       Together  130625.44        0         2  2013-04-13
# 73762    2n Cycle           YOLO  399900.54        0         0  2013-06-10
# 493    Graduation          Alone   88257.58        0         1  2013-08-21
#
#        Recency  MntWines  MntFruits  MntMeatProducts  MntFishProducts  \
# 79233        6       304        107              343              162
# 83689       66       688        149             1158               79
# 47005       80       448         73              938               61
# 73762       81       817         77             1087              184
# 493         43      1440         61              827              241
#
#        MntSweetProducts  MntGoldProds  NumDealsPurchases  NumWebPurchases  \
# 79233                 0            58                  3                0
# 83689               196            45                 13               23
# 47005                 3           326                  1                9
# 73762               259           191                  3               23
# 493                 241           173                  6               23
#
#        NumCatalogPurchases  NumStorePurchases  NumWebVisitsMonth  \
# 79233                    4                  1                  0
# 83689                   20                  5                 12
# 47005                   16                  0                 19
# 73762                    1                  7                  8
# 493                      0                 12                 13
#
#        AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  AcceptedCmp1  AcceptedCmp2  \
# 79233             0             1             0             0             1
# 83689             0             1             1             0             1
# 47005             0             1             0             1             1
# 73762             0             0             0             0             0
# 493               1             0             1             0             1
#
#        Complain  Response  Age    Age_Group Gen_Group  DaysAsCustomer  \
# 79233         0         1   64       Senior   Boomers            3601
# 83689         0         0   61       Senior   Boomers            3298
# 47005         1         0  116  Late Senior   Boomers            3457
# 73762         1         0  115  Late Senior   Boomers            3399
# 493           0         0   64       Senior   Boomers            3327
#
#        NumChildren  NumAcceptedCmp  Total_Purchases  Total_Spending  \
# 79233            3               3                8             974
# 83689            1               3               61            2315
# 47005            2               3               26            1849
# 73762            0               0               34            2615
# 493              1               3               41            2983
#
#        Conversion_Rate
# 79233              inf
# 83689              0.2
# 47005              0.2
# 73762              0.0
# 493                0.2

# %%
df.shape
# Out:
# (100279, 34)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100279 entries, 0 to 100278
# Data columns (total 34 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Education            100279 non-null  object
#  1   Marital_Status       100279 non-null  object
#  2   Income               100279 non-null  float64
#  3   Kidhome              100279 non-null  int64
#  4   Teenhome             100279 non-null  int64
#  5   Dt_Customer          100279 non-null  object
#  6   Recency              100279 non-null  int64
#  7   MntWines             100279 non-null  int64
#  8   MntFruits            100279 non-null  int64
#  9   MntMeatProducts      100279 non-null  int64
#  10  MntFishProducts      100279 non-null  int64
#  11  MntSweetProducts     100279 non-null  int64
#  12  MntGoldProds         100279 non-null  int64
#  13  NumDealsPurchases    100279 non-null  int64
#  14  NumWebPurchases      100279 non-null  int64
#  15  NumCatalogPurchases  100279 non-null  int64
#  16  NumStorePurchases    100279 non-null  int64
#  17  NumWebVisitsMonth    100279 non-null  int64
#  18  AcceptedCmp3         100279 non-null  int64
#  19  AcceptedCmp4         100279 non-null  int64
#  20  AcceptedCmp5         100279 non-null  int64
#  21  AcceptedCmp1         100279 non-null  int64
#  22  AcceptedCmp2         100279 non-null  int64
#  23  Complain             100279 non-null  int64
#  24  Response             100279 non-null  int64
#  25  Age                  100279 non-null  int64
#  26  Age_Group            100279 non-null  object
#  27  Gen_Group            99272 non-null   object
#  28  DaysAsCustomer       100279 non-null  int64
#  29  NumChildren          100279 non-null  int64
#  30  NumAcceptedCmp       100279 non-null  int64
#  31  Total_Purchases      100279 non-null  int64
#  32  Total_Spending       100279 non-null  int64
#  33  Conversion_Rate      100279 non-null  float64
# dtypes: float64(2), int64(27), object(5)
# memory usage: 26.0+ MB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop(['Kidhome', 'Teenhome',
       'Dt_Customer', 'MntWines', 'MntFruits', 'MntMeatProducts',
       'MntFishProducts', 'MntSweetProducts', 'MntGoldProds',
       'NumDealsPurchases', 'NumWebPurchases', 'NumCatalogPurchases',
       'NumStorePurchases', 'AcceptedCmp3',
       'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1', 'AcceptedCmp2',
       'Response'], axis=1, inplace=True)

# %%
# Correlation of the data
high correlation

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

numeric_df = df.select_dtypes(include=['number'])

correlation_matrix = numeric_df.corr()

plt.figure(figsize=(16, 12))

sns.heatmap(correlation_matrix, annot=True, fmt='.2f', linewidths=1, cmap='coolwarm')

plt.tight_layout()

plt.show()
