# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv('Marketing_Campaign_Dataset.csv')
data.head()
# Out:
#    ID  Year_Birth   Education Marital_Status     Income  Kidhome  Teenhome  \
# 0   1        1978      Master         Single  491796.22        1         0
# 1   2        1974      Master        Married  513926.78        1         0
# 2   3        1972  Graduation          Alone  521309.22        2         2
# 3   4        1911         PhD           YOLO  231628.91        1         0
# 4   5        1931    2n Cycle       Divorced  223936.10        1         1
#
#   Dt_Customer  Recency  MntWines  ...  NumWebVisitsMonth  AcceptedCmp3  \
# 0  2013-12-26       31      1364  ...                 14             1
# 1  2014-05-04       23      1275  ...                  5             1
# 2  2013-02-15       93        62  ...                  1             1
# 3  2013-06-12       13       251  ...                 14             0
# 4  2013-05-30       65       670  ...                 13             1
#
#    AcceptedCmp4  AcceptedCmp5  AcceptedCmp1  AcceptedCmp2  Complain  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100279 entries, 0 to 100278
# Data columns (total 29 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ID                   100279 non-null  int64
#  1   Year_Birth           100279 non-null  int64
#  2   Education            100279 non-null  object
#  3   Marital_Status       100279 non-null  object
#  4   Income               100279 non-null  float64
#  5   Kidhome              100279 non-null  int64
#  6   Teenhome             100279 non-null  int64
#  7   Dt_Customer          100279 non-null  object
#  8   Recency              100279 non-null  int64
#  9   MntWines             100279 non-null  int64
#  10  MntFruits            100279 non-null  int64
#  11  MntMeatProducts      100279 non-null  int64
#  12  MntFishProducts      100279 non-null  int64
#  13  MntSweetProducts     100279 non-null  int64
#  14  MntGoldProds         100279 non-null  int64
# ...

# %%
data.isnull().sum()
# Out:
# ID                     0
# Year_Birth             0
# Education              0
# Marital_Status         0
# Income                 0
# Kidhome                0
# Teenhome               0
# Dt_Customer            0
# Recency                0
# MntWines               0
# MntFruits              0
# MntMeatProducts        0
# MntFishProducts        0
# MntSweetProducts       0
# MntGoldProds           0
# NumDealsPurchases      0
# NumWebPurchases        0
# NumCatalogPurchases    0
# NumStorePurchases      0
# NumWebVisitsMonth      0
# AcceptedCmp3           0
# AcceptedCmp4           0
# AcceptedCmp5           0
# AcceptedCmp1           0
# AcceptedCmp2           0
# Complain               0
# Z_CostContact          0
# Z_Revenue              0
# Response               0
# dtype: int64

# %%
data.head()
# Out:
#    ID  Year_Birth   Education Marital_Status     Income  Kidhome  Teenhome  \
# 0   1        1978      Master         Single  491796.22        1         0
# 1   2        1974      Master        Married  513926.78        1         0
# 2   3        1972  Graduation          Alone  521309.22        2         2
# 3   4        1911         PhD           YOLO  231628.91        1         0
# 4   5        1931    2n Cycle       Divorced  223936.10        1         1
#
#   Dt_Customer  Recency  MntWines  ...  NumWebVisitsMonth  AcceptedCmp3  \
# 0  2013-12-26       31      1364  ...                 14             1
# 1  2014-05-04       23      1275  ...                  5             1
# 2  2013-02-15       93        62  ...                  1             1
# 3  2013-06-12       13       251  ...                 14             0
# 4  2013-05-30       65       670  ...                 13             1
#
#    AcceptedCmp4  AcceptedCmp5  AcceptedCmp1  AcceptedCmp2  Complain  \
# ...

# %%
data['Education'].unique()
# Out:
# array(['Master', 'Graduation', 'PhD', '2n Cycle', 'Basic'], dtype=object)

# %%
data['Marital_Status'].unique()
# Out:
# array(['Single', 'Married', 'Alone', 'YOLO', 'Divorced', 'Together',
#        'Widow', 'Absurd'], dtype=object)

# %%
val = data['Marital_Status'].value_counts()

# %%
plt.bar(val.index,val)
plt.show()

# %%
val = data['Year_Birth'].unique()

# %%
len(val)
# Out:
# 103

# %%
plt.scatter(val,range(103))

# %%
data.drop(['ID','Year_Birth'],inplace = True,axis=1)

# %%
data.head()
# Out:
#     Education Marital_Status     Income  Kidhome  Teenhome Dt_Customer  \
# 0      Master         Single  491796.22        1         0  2013-12-26
# 1      Master        Married  513926.78        1         0  2014-05-04
# 2  Graduation          Alone  521309.22        2         2  2013-02-15
# 3         PhD           YOLO  231628.91        1         0  2013-06-12
# 4    2n Cycle       Divorced  223936.10        1         1  2013-05-30
#
#    Recency  MntWines  MntFruits  MntMeatProducts  ...  NumWebVisitsMonth  \
# 0       31      1364         72             1129  ...                 14
# 1       23      1275         94              455  ...                  5
# 2       93        62        127              530  ...                  1
# 3       13       251         87             1153  ...                 14
# 4       65       670         10              650  ...                 13
#
#    AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  AcceptedCmp1  AcceptedCmp2  \
# ...

# %%
val = data.drop(['Dt_Customer'],axis =1).copy()

# %%
val.head()
# Out:
#     Education Marital_Status     Income  Kidhome  Teenhome  Recency  MntWines  \
# 0      Master         Single  491796.22        1         0       31      1364
# 1      Master        Married  513926.78        1         0       23      1275
# 2  Graduation          Alone  521309.22        2         2       93        62
# 3         PhD           YOLO  231628.91        1         0       13       251
# 4    2n Cycle       Divorced  223936.10        1         1       65       670
#
#    MntFruits  MntMeatProducts  MntFishProducts  ...  NumWebVisitsMonth  \
# 0         72             1129               45  ...                 14
# 1         94              455              217  ...                  5
# 2        127              530              252  ...                  1
# 3         87             1153              157  ...                 14
# 4         10              650               34  ...                 13
#
# ...

# %%
val.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100279 entries, 0 to 100278
# Data columns (total 26 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Education            100279 non-null  object
#  1   Marital_Status       100279 non-null  object
#  2   Income               100279 non-null  float64
#  3   Kidhome              100279 non-null  int64
#  4   Teenhome             100279 non-null  int64
#  5   Recency              100279 non-null  int64
#  6   MntWines             100279 non-null  int64
#  7   MntFruits            100279 non-null  int64
#  8   MntMeatProducts      100279 non-null  int64
#  9   MntFishProducts      100279 non-null  int64
#  10  MntSweetProducts     100279 non-null  int64
#  11  MntGoldProds         100279 non-null  int64
#  12  NumDealsPurchases    100279 non-null  int64
#  13  NumWebPurchases      100279 non-null  int64
#  14  NumCatalogPurchases  100279 non-null  int64
# ...

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()

# %%
val.head()
# Out:
#     Education Marital_Status     Income  Kidhome  Teenhome  Recency  MntWines  \
# 0      Master         Single  491796.22        1         0       31      1364
# 1      Master        Married  513926.78        1         0       23      1275
# 2  Graduation          Alone  521309.22        2         2       93        62
# 3         PhD           YOLO  231628.91        1         0       13       251
# 4    2n Cycle       Divorced  223936.10        1         1       65       670
#
#    MntFruits  MntMeatProducts  MntFishProducts  ...  NumWebVisitsMonth  \
# 0         72             1129               45  ...                 14
# 1         94              455              217  ...                  5
# 2        127              530              252  ...                  1
# 3         87             1153              157  ...                 14
# 4         10              650               34  ...                 13
#
# ...

# %%
val['Education'] = label.fit_transform(val['Education'])

# %%
val.head()
# Out:
#    Education Marital_Status     Income  Kidhome  Teenhome  Recency  MntWines  \
# 0          3         Single  491796.22        1         0       31      1364
# 1          3        Married  513926.78        1         0       23      1275
# 2          2          Alone  521309.22        2         2       93        62
# 3          4           YOLO  231628.91        1         0       13       251
# 4          0       Divorced  223936.10        1         1       65       670
#
#    MntFruits  MntMeatProducts  MntFishProducts  ...  NumWebVisitsMonth  \
# 0         72             1129               45  ...                 14
# 1         94              455              217  ...                  5
# 2        127              530              252  ...                  1
# 3         87             1153              157  ...                 14
# 4         10              650               34  ...                 13
#
#    AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  AcceptedCmp1  AcceptedCmp2  \
# ...

# %%
val['Education'].value_counts()
# Out:
# Education
# 1    20282
# 4    20029
# 2    20021
# 3    19978
# 0    19969
# Name: count, dtype: int64

# %%
val['Marital_Status'] = label.fit_transform(val['Marital_Status'])

# %%
val.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100279 entries, 0 to 100278
# Data columns (total 26 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Education            100279 non-null  int32
#  1   Marital_Status       100279 non-null  int32
#  2   Income               100279 non-null  float64
#  3   Kidhome              100279 non-null  int64
#  4   Teenhome             100279 non-null  int64
#  5   Recency              100279 non-null  int64
#  6   MntWines             100279 non-null  int64
#  7   MntFruits            100279 non-null  int64
#  8   MntMeatProducts      100279 non-null  int64
#  9   MntFishProducts      100279 non-null  int64
#  10  MntSweetProducts     100279 non-null  int64
#  11  MntGoldProds         100279 non-null  int64
#  12  NumDealsPurchases    100279 non-null  int64
#  13  NumWebPurchases      100279 non-null  int64
#  14  NumCatalogPurchases  100279 non-null  int64
# ...

# %%
val.head()
# Out:
#    Education  Marital_Status     Income  Kidhome  Teenhome  Recency  MntWines  \
# 0          3               4  491796.22        1         0       31      1364
# 1          3               3  513926.78        1         0       23      1275
# 2          2               1  521309.22        2         2       93        62
# 3          4               7  231628.91        1         0       13       251
# 4          0               2  223936.10        1         1       65       670
#
#    MntFruits  MntMeatProducts  MntFishProducts  ...  NumWebVisitsMonth  \
# 0         72             1129               45  ...                 14
# 1         94              455              217  ...                  5
# 2        127              530              252  ...                  1
# 3         87             1153              157  ...                 14
# 4         10              650               34  ...                 13
#
# ...

# %%
data['Z_Revenue'].unique()
# Out:
# array([11], dtype=int64)

# %%
val.drop(['Z_Revenue'],axis = 1,inplace = True)

# %%
val.head()
# Out:
#    Education  Marital_Status     Income  Kidhome  Teenhome  Recency  MntWines  \
# 0          3               4  491796.22        1         0       31      1364
# 1          3               3  513926.78        1         0       23      1275
# 2          2               1  521309.22        2         2       93        62
# 3          4               7  231628.91        1         0       13       251
# 4          0               2  223936.10        1         1       65       670
#
#    MntFruits  MntMeatProducts  MntFishProducts  ...  NumStorePurchases  \
# 0         72             1129               45  ...                  6
# 1         94              455              217  ...                  9
# 2        127              530              252  ...                  1
# 3         87             1153              157  ...                  3
# 4         10              650               34  ...                  4
#
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
val['Z_CostContact'].unique()
# Out:
# array([3], dtype=int64)

# %%
val.drop(['Z_CostContact'],axis = 1,inplace = True)

# %%
val.head()
# Out:
#    Education  Marital_Status     Income  Kidhome  Teenhome  Recency  MntWines  \
# 0          3               4  491796.22        1         0       31      1364
# 1          3               3  513926.78        1         0       23      1275
# 2          2               1  521309.22        2         2       93        62
# 3          4               7  231628.91        1         0       13       251
# 4          0               2  223936.10        1         1       65       670
#
#    MntFruits  MntMeatProducts  MntFishProducts  ...  NumCatalogPurchases  \
# 0         72             1129               45  ...                   21
# 1         94              455              217  ...                   14
# 2        127              530              252  ...                   18
# 3         87             1153              157  ...                   18
# 4         10              650               34  ...                   23
#
# ...

# %%
data['Complain'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
X = val.drop(['Response'],axis =1)
Y = val['Response']

# %%
X.head()
# Out:
#    Education  Marital_Status     Income  Kidhome  Teenhome  Recency  MntWines  \
# 0          3               4  491796.22        1         0       31      1364
# 1          3               3  513926.78        1         0       23      1275
# 2          2               1  521309.22        2         2       93        62
# 3          4               7  231628.91        1         0       13       251
# 4          0               2  223936.10        1         1       65       670
#
#    MntFruits  MntMeatProducts  MntFishProducts  ...  NumWebPurchases  \
# 0         72             1129               45  ...                1
# 1         94              455              217  ...                8
# 2        127              530              252  ...               26
# 3         87             1153              157  ...               26
# 4         10              650               34  ...                2
#
#    NumCatalogPurchases  NumStorePurchases  NumWebVisitsMonth  AcceptedCmp3  \
# ...

# %%
X.tail()
# Out:
#         Education  Marital_Status     Income  Kidhome  Teenhome  Recency  \
# 100274          4               0  135662.71        2         1       89
# 100275          2               2  622939.79        2         2       36
# 100276          2               2  410351.37        2         2       90
# 100277          1               7   64094.50        2         2       84
# 100278          1               4   96606.74        2         1       79
#
#         MntWines  MntFruits  MntMeatProducts  MntFishProducts  ...  \
# 100274        48         87             1208              178  ...
# 100275         8         92             1591               37  ...
# 100276       813         91              990               47  ...
# 100277       535          1             1640              137  ...
# 100278       628         19              565              249  ...
#
#         NumWebPurchases  NumCatalogPurchases  NumStorePurchases  \
# ...

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100279 entries, 0 to 100278
# Data columns (total 23 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Education            100279 non-null  int32
#  1   Marital_Status       100279 non-null  int32
#  2   Income               100279 non-null  float64
#  3   Kidhome              100279 non-null  int64
#  4   Teenhome             100279 non-null  int64
#  5   Recency              100279 non-null  int64
#  6   MntWines             100279 non-null  int64
#  7   MntFruits            100279 non-null  int64
#  8   MntMeatProducts      100279 non-null  int64
#  9   MntFishProducts      100279 non-null  int64
#  10  MntSweetProducts     100279 non-null  int64
#  11  MntGoldProds         100279 non-null  int64
#  12  NumDealsPurchases    100279 non-null  int64
#  13  NumWebPurchases      100279 non-null  int64
#  14  NumCatalogPurchases  100279 non-null  int64
# ...

# %%
cols = X.columns

# %%
cols
# Out:
# Index(['Education', 'Marital_Status', 'Income', 'Kidhome', 'Teenhome',
#        'Recency', 'MntWines', 'MntFruits', 'MntMeatProducts',
#        'MntFishProducts', 'MntSweetProducts', 'MntGoldProds',
#        'NumDealsPurchases', 'NumWebPurchases', 'NumCatalogPurchases',
#        'NumStorePurchases', 'NumWebVisitsMonth', 'AcceptedCmp3',
#        'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1', 'AcceptedCmp2',
#        'Complain'],
#       dtype='object')

# %%
X.corr()
# Out:
#                      Education  Marital_Status    Income   Kidhome  Teenhome  \
# Education             1.000000       -0.002692 -0.001152 -0.007253  0.002212
# Marital_Status       -0.002692        1.000000 -0.000555 -0.000426 -0.000617
# Income               -0.001152       -0.000555  1.000000  0.001870  0.001216
# Kidhome              -0.007253       -0.000426  0.001870  1.000000  0.003434
# Teenhome              0.002212       -0.000617  0.001216  0.003434  1.000000
# Recency              -0.000321        0.001677  0.005679 -0.003865  0.003093
# MntWines             -0.003878        0.000750 -0.002586  0.004614  0.004564
# MntFruits            -0.002459        0.001438  0.002470 -0.003970  0.001498
# MntMeatProducts      -0.003218       -0.002504 -0.002772  0.002375  0.005392
# MntFishProducts       0.004904        0.004203 -0.001350 -0.002671 -0.005173
# MntSweetProducts     -0.000696       -0.001265 -0.002868 -0.003470 -0.003094
# ...

# %%
X = pd.DataFrame(scaler.fit_transform(X), columns=X.columns)

# %%
X.head()
# Out:
#    Education  Marital_Status    Income   Kidhome  Teenhome   Recency  \
# 0   0.708946        0.216092  0.825242 -0.002255 -1.224159 -0.630983
# 1   0.708946       -0.219721  0.940592 -0.002255 -1.224159 -0.911377
# 2   0.001298       -1.091347  0.979071  1.220315  1.224794  1.542065
# 3   1.416593        1.523532 -0.530807 -0.002255 -1.224159 -1.261868
# 4  -1.413996       -0.655534 -0.570904 -0.002255  0.000317  0.560688
#
#    MntWines  MntFruits  MntMeatProducts  MntFishProducts  ...  \
# 0  1.430667  -0.471812         0.535116        -1.126251  ...
# 1  1.224478  -0.088556        -0.815740         1.171321  ...
# 2 -1.585719   0.486327        -0.665422         1.638850  ...
# 3 -1.147857  -0.210501         0.583218         0.369842  ...
# 4 -0.177145  -1.551895        -0.424913        -1.273189  ...
#
#    NumWebPurchases  NumCatalogPurchases  NumStorePurchases  NumWebVisitsMonth  \
# 0        -1.538217             0.926777          -0.002516           0.779848
# ...

# %%
X.corr()
# Out:
#                      Education  Marital_Status    Income   Kidhome  Teenhome  \
# Education             1.000000       -0.002692 -0.001152 -0.007253  0.002212
# Marital_Status       -0.002692        1.000000 -0.000555 -0.000426 -0.000617
# Income               -0.001152       -0.000555  1.000000  0.001870  0.001216
# Kidhome              -0.007253       -0.000426  0.001870  1.000000  0.003434
# Teenhome              0.002212       -0.000617  0.001216  0.003434  1.000000
# Recency              -0.000321        0.001677  0.005679 -0.003865  0.003093
# MntWines             -0.003878        0.000750 -0.002586  0.004614  0.004564
# MntFruits            -0.002459        0.001438  0.002470 -0.003970  0.001498
# MntMeatProducts      -0.003218       -0.002504 -0.002772  0.002375  0.005392
# MntFishProducts       0.004904        0.004203 -0.001350 -0.002671 -0.005173
# MntSweetProducts     -0.000696       -0.001265 -0.002868 -0.003470 -0.003094
# ...

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
val.head()
# Out:
#    Education  Marital_Status     Income  Kidhome  Teenhome  Recency  MntWines  \
# 0          3               4  491796.22        1         0       31      1364
# 1          3               3  513926.78        1         0       23      1275
# 2          2               1  521309.22        2         2       93        62
# 3          4               7  231628.91        1         0       13       251
# 4          0               2  223936.10        1         1       65       670
#
#    MntFruits  MntMeatProducts  MntFishProducts  ...  NumCatalogPurchases  \
# 0         72             1129               45  ...                   21
# 1         94              455              217  ...                   14
# 2        127              530              252  ...                   18
# 3         87             1153              157  ...                   18
# 4         10              650               34  ...                   23
#
# ...

# %%
val = pd.DataFrame(scaler.fit_transform(val),columns = val.columns)

# %%
val.head()
# Out:
#    Education  Marital_Status    Income   Kidhome  Teenhome   Recency  \
# 0   0.708946        0.216092  0.825242 -0.002255 -1.224159 -0.630983
# 1   0.708946       -0.219721  0.940592 -0.002255 -1.224159 -0.911377
# 2   0.001298       -1.091347  0.979071  1.220315  1.224794  1.542065
# 3   1.416593        1.523532 -0.530807 -0.002255 -1.224159 -1.261868
# 4  -1.413996       -0.655534 -0.570904 -0.002255  0.000317  0.560688
#
#    MntWines  MntFruits  MntMeatProducts  MntFishProducts  ...  \
# 0  1.430667  -0.471812         0.535116        -1.126251  ...
# 1  1.224478  -0.088556        -0.815740         1.171321  ...
# 2 -1.585719   0.486327        -0.665422         1.638850  ...
# 3 -1.147857  -0.210501         0.583218         0.369842  ...
# 4 -0.177145  -1.551895        -0.424913        -1.273189  ...
#
#    NumCatalogPurchases  NumStorePurchases  NumWebVisitsMonth  AcceptedCmp3  \
# 0             0.926777          -0.002516           0.779848      0.995731
# ...

# %%
val.isnull().sum()
# Out:
# Education              0
# Marital_Status         0
# Income                 0
# Kidhome                0
# Teenhome               0
# Recency                0
# MntWines               0
# MntFruits              0
# MntMeatProducts        0
# MntFishProducts        0
# MntSweetProducts       0
# MntGoldProds           0
# NumDealsPurchases      0
# NumWebPurchases        0
# NumCatalogPurchases    0
# NumStorePurchases      0
# NumWebVisitsMonth      0
# AcceptedCmp3           0
# AcceptedCmp4           0
# AcceptedCmp5           0
# AcceptedCmp1           0
# AcceptedCmp2           0
# Complain               0
# Response               0
# dtype: int64

# %%
import seaborn as sns

# %%
sns.boxplot(val)
plt.xticks(rotation = 90)
plt.show()

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans, DBSCAN
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.preprocessing import StandardScaler

# %%
val.head()
# Out:
#    Education  Marital_Status    Income   Kidhome  Teenhome   Recency  \
# 0   0.708946        0.216092  0.825242 -0.002255 -1.224159 -0.630983
# 1   0.708946       -0.219721  0.940592 -0.002255 -1.224159 -0.911377
# 2   0.001298       -1.091347  0.979071  1.220315  1.224794  1.542065
# 3   1.416593        1.523532 -0.530807 -0.002255 -1.224159 -1.261868
# 4  -1.413996       -0.655534 -0.570904 -0.002255  0.000317  0.560688
#
#    MntWines  MntFruits  MntMeatProducts  MntFishProducts  ...  \
# 0  1.430667  -0.471812         0.535116        -1.126251  ...
# 1  1.224478  -0.088556        -0.815740         1.171321  ...
# 2 -1.585719   0.486327        -0.665422         1.638850  ...
# 3 -1.147857  -0.210501         0.583218         0.369842  ...
# 4 -0.177145  -1.551895        -0.424913        -1.273189  ...
#
#    NumCatalogPurchases  NumStorePurchases  NumWebVisitsMonth  AcceptedCmp3  \
# 0             0.926777          -0.002516           0.779848      0.995731
# ...

# %%
val.corr()
# Out:
#                      Education  Marital_Status    Income   Kidhome  Teenhome  \
# Education             1.000000       -0.002692 -0.001152 -0.007253  0.002212
# Marital_Status       -0.002692        1.000000 -0.000555 -0.000426 -0.000617
# Income               -0.001152       -0.000555  1.000000  0.001870  0.001216
# Kidhome              -0.007253       -0.000426  0.001870  1.000000  0.003434
# Teenhome              0.002212       -0.000617  0.001216  0.003434  1.000000
# Recency              -0.000321        0.001677  0.005679 -0.003865  0.003093
# MntWines             -0.003878        0.000750 -0.002586  0.004614  0.004564
# MntFruits            -0.002459        0.001438  0.002470 -0.003970  0.001498
# MntMeatProducts      -0.003218       -0.002504 -0.002772  0.002375  0.005392
# MntFishProducts       0.004904        0.004203 -0.001350 -0.002671 -0.005173
# MntSweetProducts     -0.000696       -0.001265 -0.002868 -0.003470 -0.003094
# ...

# %%
val.head()
# Out:
#    Education  Marital_Status    Income   Kidhome  Teenhome   Recency  \
# 0   0.708946        0.216092  0.825242 -0.002255 -1.224159 -0.630983
# 1   0.708946       -0.219721  0.940592 -0.002255 -1.224159 -0.911377
# 2   0.001298       -1.091347  0.979071  1.220315  1.224794  1.542065
# 3   1.416593        1.523532 -0.530807 -0.002255 -1.224159 -1.261868
# 4  -1.413996       -0.655534 -0.570904 -0.002255  0.000317  0.560688
#
#    MntWines  MntFruits  MntMeatProducts  MntFishProducts  ...  \
# 0  1.430667  -0.471812         0.535116        -1.126251  ...
# 1  1.224478  -0.088556        -0.815740         1.171321  ...
# 2 -1.585719   0.486327        -0.665422         1.638850  ...
# 3 -1.147857  -0.210501         0.583218         0.369842  ...
# 4 -0.177145  -1.551895        -0.424913        -1.273189  ...
#
#    NumCatalogPurchases  NumStorePurchases  NumWebVisitsMonth  AcceptedCmp3  \
# 0             0.926777          -0.002516           0.779848      0.995731
# ...

# %%
data.head()
# Out:
#     Education Marital_Status     Income  Kidhome  Teenhome Dt_Customer  \
# 0      Master         Single  491796.22        1         0  2013-12-26
# 1      Master        Married  513926.78        1         0  2014-05-04
# 2  Graduation          Alone  521309.22        2         2  2013-02-15
# 3         PhD           YOLO  231628.91        1         0  2013-06-12
# 4    2n Cycle       Divorced  223936.10        1         1  2013-05-30
#
#    Recency  MntWines  MntFruits  MntMeatProducts  ...  NumWebVisitsMonth  \
# 0       31      1364         72             1129  ...                 14
# 1       23      1275         94              455  ...                  5
# 2       93        62        127              530  ...                  1
# 3       13       251         87             1153  ...                 14
# 4       65       670         10              650  ...                 13
#
#    AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  AcceptedCmp1  AcceptedCmp2  \
# ...

# %%
plt.bar(data['Marital_Status'].value_counts(),data['Marital_Status'].unique(),width = 20)
# Out:
# <BarContainer object of 8 artists>

# %%
kmeans = KMeans(n_clusters = 2, random_state = 42)

# %%
kmeans.fit(val)
# Out:
# KMeans(n_clusters=2, random_state=42)

# %%
label = kmeans.labels_
label
# Out:
# array([1, 1, 1, ..., 0, 0, 0])

# %%
center = kmeans.cluster_centers_
center
# Out:
# array([[ 1.55270840e-03,  2.63527871e-03, -3.15715469e-03,
#         -4.79348619e-03,  2.68593864e-04, -6.70508285e-04,
#          5.22345831e-04, -2.22499551e-03, -1.52711921e-03,
#          2.52544900e-03, -1.72592693e-03,  5.63309571e-03,
#          2.98581994e-03,  1.49431947e-04,  1.03614264e-03,
#          3.51277591e-04,  1.23716809e-03,  1.05160588e-03,
#         -6.07947838e-04, -1.76509505e-03,  7.59185192e-03,
#         -8.66200400e-05,  1.00084799e+00, -1.50879673e-03],
#        [-1.55007837e-03, -2.63081498e-03,  3.15180699e-03,
#          4.78536682e-03, -2.68138910e-04,  6.69372555e-04,
#         -5.21461063e-04,  2.22122673e-03,  1.52453252e-03,
#         -2.52117130e-03,  1.72300349e-03, -5.62355418e-03,
#         -2.98076245e-03, -1.49178834e-04, -1.03438759e-03,
#         -3.50682585e-04, -1.23507254e-03, -1.04982463e-03,
#          6.06918075e-04,  1.76210527e-03, -7.57899258e-03,
#          8.64733199e-05, -9.99152724e-01,  1.50624108e-03]])

# %%
val.head()
# Out:
#    Education  Marital_Status    Income   Kidhome  Teenhome   Recency  \
# 0   0.708946        0.216092  0.825242 -0.002255 -1.224159 -0.630983
# 1   0.708946       -0.219721  0.940592 -0.002255 -1.224159 -0.911377
# 2   0.001298       -1.091347  0.979071  1.220315  1.224794  1.542065
# 3   1.416593        1.523532 -0.530807 -0.002255 -1.224159 -1.261868
# 4  -1.413996       -0.655534 -0.570904 -0.002255  0.000317  0.560688
#
#    MntWines  MntFruits  MntMeatProducts  MntFishProducts  ...  \
# 0  1.430667  -0.471812         0.535116        -1.126251  ...
# 1  1.224478  -0.088556        -0.815740         1.171321  ...
# 2 -1.585719   0.486327        -0.665422         1.638850  ...
# 3 -1.147857  -0.210501         0.583218         0.369842  ...
# 4 -0.177145  -1.551895        -0.424913        -1.273189  ...
#
#    NumCatalogPurchases  NumStorePurchases  NumWebVisitsMonth  AcceptedCmp3  \
# 0             0.926777          -0.002516           0.779848      0.995731
# ...

# %%
labels = kmeans.fit_predict(val)
val['Cluster'] = labels

# %%
val['Cluster'].unique()
# Out:
# array([1, 0])

# %%
val['Cluster'].value_counts()
# Out:
# Cluster
# 1    50182
# 0    50097
# Name: count, dtype: int64

# %%
plt.scatter(val.iloc[:, 0], val.iloc[:, 1], c=labels, cmap='viridis', alpha=0.7)
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], c='red', marker='x', s=200, label='Centroids')
plt.legend()
plt.show()

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)  
val_pca = pca.fit_transform(val.drop(columns=['Cluster']))  

plt.scatter(val_pca[:, 0], val_pca[:, 1], c=labels, cmap='viridis', alpha=0.7)
plt.scatter(pca.transform(kmeans.cluster_centers_)[:, 0], pca.transform(kmeans.cluster_centers_)[:, 1], c='red', marker='x', s=200, label='Centroids')
plt.legend()
plt.show()

# %%
print("Inertia:", kmeans.inertia_)
# Out:
# Inertia: 2306400.217429911

# %%
val
# Out:
#         Education  Marital_Status    Income   Kidhome  Teenhome   Recency  \
# 0        0.708946        0.216092  0.825242 -0.002255 -1.224159 -0.630983
# 1        0.708946       -0.219721  0.940592 -0.002255 -1.224159 -0.911377
# 2        0.001298       -1.091347  0.979071  1.220315  1.224794  1.542065
# 3        1.416593        1.523532 -0.530807 -0.002255 -1.224159 -1.261868
# 4       -1.413996       -0.655534 -0.570904 -0.002255  0.000317  0.560688
# ...           ...             ...       ...       ...       ...       ...
# 100274   1.416593       -1.527161 -1.031004  1.220315  0.000317  1.401869
# 100275   0.001298       -0.655534  1.508792  1.220315  1.224794 -0.455737
# 100276   0.001298       -0.655534  0.400734  1.220315  1.224794  1.436918
# 100277  -0.706349        1.523532 -1.404033  1.220315  1.224794  1.226623
# 100278  -0.706349        0.216092 -1.234572  1.220315  0.000317  1.051377
#
#         MntWines  MntFruits  MntMeatProducts  MntFishProducts  ...  \
# ...

# %%
val.corr()
# Out:
#                      Education  Marital_Status    Income   Kidhome  Teenhome  \
# Education             1.000000       -0.002692 -0.001152 -0.007253  0.002212
# Marital_Status       -0.002692        1.000000 -0.000555 -0.000426 -0.000617
# Income               -0.001152       -0.000555  1.000000  0.001870  0.001216
# Kidhome              -0.007253       -0.000426  0.001870  1.000000  0.003434
# Teenhome              0.002212       -0.000617  0.001216  0.003434  1.000000
# Recency              -0.000321        0.001677  0.005679 -0.003865  0.003093
# MntWines             -0.003878        0.000750 -0.002586  0.004614  0.004564
# MntFruits            -0.002459        0.001438  0.002470 -0.003970  0.001498
# MntMeatProducts      -0.003218       -0.002504 -0.002772  0.002375  0.005392
# MntFishProducts       0.004904        0.004203 -0.001350 -0.002671 -0.005173
# MntSweetProducts     -0.000696       -0.001265 -0.002868 -0.003470 -0.003094
# ...
